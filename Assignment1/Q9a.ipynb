# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Q9_a.csv')
df
# Out:
#     Index  speed  dist
# 0       1      4     2
# 1       2      4    10
# 2       3      7     4
# 3       4      7    22
# 4       5      8    16
# 5       6      9    10
# 6       7     10    18
# 7       8     10    26
# 8       9     10    34
# 9      10     11    17
# 10     11     11    28
# 11     12     12    14
# 12     13     12    20
# 13     14     12    24
# 14     15     12    28
# 15     16     13    26
# 16     17     13    34
# 17     18     13    34
# 18     19     13    46
# 19     20     14    26
# 20     21     14    36
# 21     22     14    60
# 22     23     14    80
# 23     24     15    20
# 24     25     15    26
# 25     26     15    54
# 26     27     16    32
# 27     28     16    40
# 28     29     17    32
# 29     30     17    40
# 30     31     17    50
# 31     32     18    42
# 32     33     18    56
# 33     34     18    76
# 34     35     18    84
# 35     36     19    36
# 36     37     19    46
# 37     38     19    68
# 38     39     20    32
# ...

# %%
print("Speed",df['speed'].skew())
print("distance",df['dist'].skew())
# Out:
# Speed -0.11750986144663393
# distance 0.8068949601674215

# %%
print("Speed",df['speed'].kurtosis())
print("distance",df['dist'].kurtosis())
# Out:
# Speed -0.5089944204057617
# distance 0.4050525816795765

# %%
plt.boxplot(df.speed)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2535e8f26a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2535e8f2c40>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2535e8f23d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2535e912220>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2535e9124f0>],
#  'means': []}

# %%
plt.boxplot(df.dist)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2535eb2cf70>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2535e93c550>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2535eb2cca0>],
#  'medians': [<matplotlib.lines.Line2D at 0x2535e93caf0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2535e93cdc0>],
#  'means': []}
