# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (10,5)
plt.rcParams['figure.dpi']= 300
import seaborn as sns
sns.set_theme(style='darkgrid',palette='rainbow')
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report ,confusion_matrix
from sklearn.preprocessing import LabelEncoder , OrdinalEncoder
# %matplotlib inline

# %%
df = pd.read_csv('SalaryData_Train(1).csv')
df
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
#                occupation    relationship    race      sex  capitalgain  \
# 0            Adm-clerical   Not-in-family   White     Male         2174
# 1         Exec-managerial         Husband   White     Male            0
# 2       Handlers-cleaners   Not-in-family   White     Male            0
# 3       Handlers-cleaners         Husband   Black     Male            0
# 4          Prof-specialty            Wife   Black   Female            0
# ...                   ...             ...     ...      ...          ...
# 30156        Tech-support            Wife   White   Female            0
# 30157   Machine-op-inspct         Husband   White     Male            0
# 30158        Adm-clerical       Unmarried   White   Female            0
# 30159        Adm-clerical       Own-child   White     Male            0
# 30160     Exec-managerial            Wife   White   Female        15024
#
#        capitalloss  hoursperweek          native  Salary
# 0                0            40   United-States   <=50K
# 1                0            13   United-States   <=50K
# 2                0            40   United-States   <=50K
# 3                0            40   United-States   <=50K
# 4                0            40            Cuba   <=50K
# ...            ...           ...             ...     ...
# 30156            0            38   United-States   <=50K
# 30157            0            40   United-States    >50K
# 30158            0            40   United-States   <=50K
# 30159            0            20   United-States   <=50K
# 30160            0            40   United-States    >50K
#
# [30161 rows x 14 columns]

# %% [markdown]
# ### Check for null and duplicate

# %%
df.describe()
# Out:
#                 age   educationno   capitalgain   capitalloss  hoursperweek
# count  30161.000000  30161.000000  30161.000000  30161.000000  30161.000000
# mean      38.438115     10.121316   1092.044064     88.302311     40.931269
# std       13.134830      2.550037   7406.466611    404.121321     11.980182
# min       17.000000      1.000000      0.000000      0.000000      1.000000
# 25%       28.000000      9.000000      0.000000      0.000000     40.000000
# 50%       37.000000     10.000000      0.000000      0.000000     40.000000
# 75%       47.000000     13.000000      0.000000      0.000000     45.000000
# max       90.000000     16.000000  99999.000000   4356.000000     99.000000

# %%
df.isna().sum()
# Out:
# age              0
# workclass        0
# education        0
# educationno      0
# maritalstatus    0
# occupation       0
# relationship     0
# race             0
# sex              0
# capitalgain      0
# capitalloss      0
# hoursperweek     0
# native           0
# Salary           0
# dtype: int64

# %%
df.drop(index=list(df[df.duplicated()].index),inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26903 entries, 0 to 30160
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   age            26903 non-null  int64
#  1   workclass      26903 non-null  object
#  2   education      26903 non-null  object
#  3   educationno    26903 non-null  int64
#  4   maritalstatus  26903 non-null  object
#  5   occupation     26903 non-null  object
#  6   relationship   26903 non-null  object
#  7   race           26903 non-null  object
#  8   sex            26903 non-null  object
#  9   capitalgain    26903 non-null  int64
#  10  capitalloss    26903 non-null  int64
#  11  hoursperweek   26903 non-null  int64
#  12  native         26903 non-null  object
#  13  Salary         26903 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.1+ MB

# %%
print(f"Non Numeric Columns : {[x for x in df.columns if df[x].dtype=='O']}")
# Out:
# Non Numeric Columns : ['workclass', 'education', 'maritalstatus', 'occupation', 'relationship', 'race', 'sex', 'native', 'Salary']

# %%
lbenc = LabelEncoder()
df['Salary']=lbenc.fit_transform(df['Salary'])

# %%
oe= OrdinalEncoder()
df[['workclass', 'education', 'maritalstatus', 'occupation', 'relationship', 'race', 'sex', 'native']] = oe.fit_transform(df[['workclass', 'education', 'maritalstatus', 'occupation', 'relationship', 'race', 'sex', 'native']])

# %%
df
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39        5.0        9.0           13            4.0         0.0
# 1       50        4.0        9.0           13            2.0         3.0
# 2       38        2.0       11.0            9            0.0         5.0
# 3       53        2.0        1.0            7            2.0         5.0
# 4       28        2.0        9.0           13            2.0         9.0
# ...    ...        ...        ...          ...            ...         ...
# 30154   53        2.0       12.0           14            2.0         3.0
# 30155   22        2.0       15.0           10            4.0        10.0
# 30156   27        2.0        7.0           12            2.0        12.0
# 30158   58        2.0       11.0            9            6.0         0.0
# 30160   52        3.0       11.0            9            2.0         3.0
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# 0               1.0   4.0  1.0         2174            0            40
# 1               0.0   4.0  1.0            0            0            13
# 2               1.0   4.0  1.0            0            0            40
# 3               0.0   2.0  1.0            0            0            40
# 4               5.0   2.0  0.0            0            0            40
# ...             ...   ...  ...          ...          ...           ...
# 30154           0.0   4.0  1.0            0            0            40
# 30155           1.0   4.0  1.0            0            0            40
# 30156           5.0   4.0  0.0            0            0            38
# 30158           4.0   4.0  0.0            0            0            40
# 30160           5.0   4.0  0.0        15024            0            40
#
#        native  Salary
# 0        37.0       0
# 1        37.0       0
# 2        37.0       0
# 3        37.0       0
# 4         4.0       0
# ...       ...     ...
# 30154    37.0       1
# 30155    37.0       0
# 30156    37.0       0
# 30158    37.0       0
# 30160    37.0       1
#
# [26903 rows x 14 columns]

# %% [markdown]
# # Visualization

# %%
sns.countplot(data=df,x='Salary')
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='count'>

# %%
sns.scatterplot(x=df['age'],y=df['education'],hue=df['Salary'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='education'>

# %%
sns.scatterplot(x=df['maritalstatus'],y=df['education'],hue=df['Salary'])
# Out:
# <AxesSubplot:xlabel='maritalstatus', ylabel='education'>

# %%
sns.scatterplot(x=df['age'],y=df['hoursperweek'],hue=df['Salary'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='hoursperweek'>

# %% [markdown]
# ## Data Preprocessing

# %%
x = df.drop('Salary',axis=1)
y= df['Salary']

# %%
std = StandardScaler()
scaled =std.fit_transform(x)
scaled
# Out:
# array([[-0.00372591,  2.79138305, -0.32451893, ..., -0.23132996,
#         -0.09432316,  0.28241436],
#        [ 0.83032903,  1.78815577, -0.32451893, ..., -0.23132996,
#         -2.28112073,  0.28241436],
#        [-0.07954909, -0.2182988 ,  0.19299932, ..., -0.23132996,
#         -0.09432316,  0.28241436],
#        ...,
#        [-0.91360403, -0.2182988 , -0.84203718, ..., -0.23132996,
#         -0.25630817,  0.28241436],
#        [ 1.43691444, -0.2182988 ,  0.19299932, ..., -0.23132996,
#         -0.09432316,  0.28241436],
#        [ 0.98197538,  0.78492849,  0.19299932, ..., -0.23132996,
#         -0.09432316,  0.28241436]])

# %% [markdown]
# ### Spliting Data

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,train_size=0.15,random_state=42)

# %% [markdown]
# # SVC

# %%
svm = SVC()
svm.fit(xtrain,ytrain)
# Out:
# SVC()

# %%
print(f"Train Score : {svm.score(xtrain,ytrain)}")
print(f"Test Score : {svm.score(xtest,ytest)}")
# Out:
# Train Score : 0.7856257744733581
# Test Score : 0.7953034808465979

# %%
ypred = svm.predict(xtest)

# %%
print('Train Report')
print(classification_report(ytrain,svm.predict(xtrain)))
# Out:
# Train Report
#               precision    recall  f1-score   support
#
#            0       0.79      0.96      0.87      2970
#            1       0.73      0.29      0.42      1065
#
#     accuracy                           0.79      4035
#    macro avg       0.76      0.63      0.64      4035
# weighted avg       0.78      0.79      0.75      4035

# %%
print(' Test Report')
print(classification_report(ytest,ypred))
# Out:
#  Test Report
#               precision    recall  f1-score   support
#
#            0       0.80      0.97      0.88     17053
#            1       0.74      0.30      0.42      5815
#
#     accuracy                           0.80     22868
#    macro avg       0.77      0.63      0.65     22868
# weighted avg       0.79      0.80      0.76     22868

# %%
sns.heatmap(confusion_matrix(ytest,ypred),annot=True,fmt='.2f')
plt.title('Confusion Matrix')
plt.ylabel('True')
plt.xlabel('Predicted')
plt.show()

# %% [markdown]
# # Hyper Parameter Tuning

# %%
params = {
    'kernel':['linear','rbf'],
    'gamma':[0.1,0.01],
    'C':[0.01,1]
}

# %%
grid=GridSearchCV(SVC(),param_grid=params,verbose=1)

# %%
grid.fit(xtrain,ytrain)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [0.01, 1], 'gamma': [0.1, 0.01],
#                          'kernel': ['linear', 'rbf']},
#              verbose=1)

# %%
grid.best_params_
# Out:
# {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}

# %%
svm.fit(xtrain,ytrain)
ypred = svm.predict(xtest)

# %%
svm.score(xtrain,ytrain), svm.score(xtest,ytest)
# Out:
# (0.7856257744733581, 0.7953034808465979)

# %% [markdown]
# # Final Model

# %%
fmodel = SVC(C=1,gamma=0.1,kernel='rbf')

# %%
fmodel.fit(xtrain,ytrain)
# Out:
# SVC(C=1, gamma=0.1)

# %%
print(f"Train Score : {fmodel.score(xtrain,ytrain)}")
print(f"Test Score : {fmodel.score(xtest,ytest)}")
# Out:
# Train Score : 0.9593556381660471
# Test Score : 0.7558159874059821

# %%
print(' Train Report')
print(classification_report(ytrain,fmodel.predict(xtrain)))
# Out:
#  Train Report
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97      2970
#            1       0.98      0.86      0.92      1065
#
#     accuracy                           0.96      4035
#    macro avg       0.97      0.93      0.95      4035
# weighted avg       0.96      0.96      0.96      4035

# %%
print(' Test Report')
print(classification_report(ytest,ypred))
# Out:
#  Test Report
#               precision    recall  f1-score   support
#
#            0       0.80      0.97      0.88     17053
#            1       0.74      0.30      0.42      5815
#
#     accuracy                           0.80     22868
#    macro avg       0.77      0.63      0.65     22868
# weighted avg       0.79      0.80      0.76     22868

# %%
sns.heatmap(confusion_matrix(ytest,ypred),annot=True,fmt='.2f')
plt.title('Confusion Matrix')
plt.ylabel('True')
plt.xlabel('Predicted')
plt.show()

# %% [markdown]
# # Prediction on Test Data

# %%
test_df = pd.read_csv('./SalaryData_Test(1).csv')
test_df
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
#                occupation    relationship                 race      sex  \
# 0       Machine-op-inspct       Own-child                Black     Male
# 1         Farming-fishing         Husband                White     Male
# 2         Protective-serv         Husband                White     Male
# 3       Machine-op-inspct         Husband                Black     Male
# 4           Other-service   Not-in-family                White     Male
# ...                   ...             ...                  ...      ...
# 15055      Prof-specialty       Own-child                White     Male
# 15056      Prof-specialty   Not-in-family                White   Female
# 15057      Prof-specialty         Husband                White     Male
# 15058        Adm-clerical       Own-child   Asian-Pac-Islander     Male
# 15059     Exec-managerial         Husband                White     Male
#
#        capitalgain  capitalloss  hoursperweek          native  Salary
# 0                0            0            40   United-States   <=50K
# 1                0            0            50   United-States   <=50K
# 2                0            0            40   United-States    >50K
# 3             7688            0            40   United-States    >50K
# 4                0            0            30   United-States   <=50K
# ...            ...          ...           ...             ...     ...
# 15055            0            0            40   United-States   <=50K
# 15056            0            0            36   United-States   <=50K
# 15057            0            0            50   United-States   <=50K
# 15058         5455            0            40   United-States   <=50K
# 15059            0            0            60   United-States    >50K
#
# [15060 rows x 14 columns]

# %%
test_df[['workclass', 'education', 'maritalstatus', 'occupation', 'relationship', 'race', 'sex', 'native']] = oe.transform(test_df[['workclass', 'education', 'maritalstatus', 'occupation', 'relationship', 'race', 'sex', 'native']])

# %%
test_df['Salary'] = lbenc.transform(test_df['Salary'])

# %%
X = test_df.drop('Salary',axis=1)
Y = test_df['Salary']

# %%
scaledX = std.transform(X)

# %%
print(f"Test Score : {fmodel.score(scaledX,Y)}")
# Out:
# E:\anaconda\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# Test Score : 0.7543160690571049

# %%
preds = fmodel.predict(scaledX)
# Out:
# E:\anaconda\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
print(' Test Report')
print(classification_report(Y,preds))
# Out:
#  Test Report
#               precision    recall  f1-score   support
#
#            0       0.75      1.00      0.86     11360
#            1       0.00      0.00      0.00      3700
#
#     accuracy                           0.75     15060
#    macro avg       0.38      0.50      0.43     15060
# weighted avg       0.57      0.75      0.65     15060
# E:\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# E:\anaconda\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
