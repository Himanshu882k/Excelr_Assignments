# %%
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from scipy.cluster import hierarchy
from sklearn.cluster import KMeans , DBSCAN
from sklearn.metrics import silhouette_score
from yellowbrick.cluster import SilhouetteVisualizer
from sklearn.neighbors import NearestNeighbors
from sklearn.cluster import AgglomerativeClustering
import numpy as np
sns.set_style('darkgrid')
plt.rcParams['figure.figsize'] = (10,5)
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('EastWestAirlines.xlsx',sheet_name='data',index_col=0)

# %%
df
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# ID#
# 1       28143           0          1          1          1          174
# 2       19244           0          1          1          1          215
# 3       41354           0          1          1          1         4123
# 4       14776           0          1          1          1          500
# 5       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 4017    18476           0          1          1          1         8525
# 4018    64385           0          1          1          1          981
# 4019    73597           0          3          1          1        25447
# 4020    54899           0          1          1          1          500
# 4021     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ID#
# 1               1                  0                0               7000
# 2               2                  0                0               6968
# 3               4                  0                0               7034
# 4               1                  0                0               6952
# 5              26               2077                4               6935
# ...           ...                ...              ...                ...
# 4017            4                200                1               1403
# 4018            5                  0                0               1395
# 4019            8                  0                0               1402
# 4020            1                500                1               1401
# 4021            0                  0                0               1398
#
#       Award?
# ID#
# 1          0
# 2          0
# 3          0
# 4          0
# 5          1
# ...      ...
# 4017       1
# 4018       1
# 4019       1
# 4020       0
# 4021       0
#
# [3999 rows x 11 columns]

# %%
df.rename(columns={'Award?':'Award'},inplace=True)

# %%
df
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# ID#
# 1       28143           0          1          1          1          174
# 2       19244           0          1          1          1          215
# 3       41354           0          1          1          1         4123
# 4       14776           0          1          1          1          500
# 5       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 4017    18476           0          1          1          1         8525
# 4018    64385           0          1          1          1          981
# 4019    73597           0          3          1          1        25447
# 4020    54899           0          1          1          1          500
# 4021     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ID#
# 1               1                  0                0               7000
# 2               2                  0                0               6968
# 3               4                  0                0               7034
# 4               1                  0                0               6952
# 5              26               2077                4               6935
# ...           ...                ...              ...                ...
# 4017            4                200                1               1403
# 4018            5                  0                0               1395
# 4019            8                  0                0               1402
# 4020            1                500                1               1401
# 4021            0                  0                0               1398
#
#       Award
# ID#
# 1         0
# 2         0
# 3         0
# 4         0
# 5         1
# ...     ...
# 4017      1
# 4018      1
# 4019      1
# 4020      0
# 4021      0
#
# [3999 rows x 11 columns]

# %% [markdown]
# # Check for null and duplicates

# %%
df.isna().sum()
# Out:
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3999 entries, 1 to 4021
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Balance            3999 non-null   int64
#  1   Qual_miles         3999 non-null   int64
#  2   cc1_miles          3999 non-null   int64
#  3   cc2_miles          3999 non-null   int64
#  4   cc3_miles          3999 non-null   int64
#  5   Bonus_miles        3999 non-null   int64
#  6   Bonus_trans        3999 non-null   int64
#  7   Flight_miles_12mo  3999 non-null   int64
#  8   Flight_trans_12    3999 non-null   int64
#  9   Days_since_enroll  3999 non-null   int64
#  10  Award              3999 non-null   int64
# dtypes: int64(11)
# memory usage: 374.9 KB

# %%
df[df.duplicated(keep=False)]
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# ID#
# 3393     1000           0          1          1          1            0
# 3899     1000           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ID#
# 3393            0                  0                0               1597
# 3899            0                  0                0               1597
#
#       Award
# ID#
# 3393      0
# 3899      0

# %%
df.drop(index=3393,inplace=True)

# %%
df
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# ID#
# 1       28143           0          1          1          1          174
# 2       19244           0          1          1          1          215
# 3       41354           0          1          1          1         4123
# 4       14776           0          1          1          1          500
# 5       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 4017    18476           0          1          1          1         8525
# 4018    64385           0          1          1          1          981
# 4019    73597           0          3          1          1        25447
# 4020    54899           0          1          1          1          500
# 4021     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ID#
# 1               1                  0                0               7000
# 2               2                  0                0               6968
# 3               4                  0                0               7034
# 4               1                  0                0               6952
# 5              26               2077                4               6935
# ...           ...                ...              ...                ...
# 4017            4                200                1               1403
# 4018            5                  0                0               1395
# 4019            8                  0                0               1402
# 4020            1                500                1               1401
# 4021            0                  0                0               1398
#
#       Award
# ID#
# 1         0
# 2         0
# 3         0
# 4         0
# 5         1
# ...     ...
# 4017      1
# 4018      1
# 4019      1
# 4020      0
# 4021      0
#
# [3998 rows x 11 columns]

# %% [markdown]
# # Visualization

# %%
sns.pairplot(df)

# %% [markdown]
# # Data preprocessing
# ## Standardization

# %%
sc = StandardScaler()
scaled=sc.fit_transform(df)
scaled
# Out:
# array([[-4.51293870e-01, -1.86322793e-01, -7.69731660e-01, ...,
#         -3.62219103e-01,  1.39523468e+00, -7.67071631e-01],
#        [-5.39604653e-01, -1.86322793e-01, -7.69731660e-01, ...,
#         -3.62219103e-01,  1.37973643e+00, -7.67071631e-01],
#        [-3.20192202e-01, -1.86322793e-01, -7.69731660e-01, ...,
#         -3.62219103e-01,  1.41170157e+00, -7.67071631e-01],
#        ...,
#        [-2.23153612e-04, -1.86322793e-01,  6.82893866e-01, ...,
#         -3.62219103e-01, -1.31599028e+00,  1.30365921e+00],
#        [-1.85776026e-01, -1.86322793e-01, -7.69731660e-01, ...,
#         -9.85832074e-02, -1.31647460e+00, -7.67071631e-01],
#        [-7.00646048e-01, -1.86322793e-01, -7.69731660e-01, ...,
#         -3.62219103e-01, -1.31792757e+00, -7.67071631e-01]])

# %% [markdown]
# # hierarical clustering

# %%
lk_ = hierarchy.linkage(scaled, method='single')
dend = hierarchy.dendrogram(lk)

# %%
lk_c = hierarchy.linkage(scaled, method='complete')
dend = hierarchy.dendrogram(lk_c)

# %%
lk_a= hierarchy.linkage(scaled, method='average')
dend = hierarchy.dendrogram(lk_a)

# %%
lk_ct = hierarchy.linkage(scaled, method='centroid')
dend = hierarchy.dendrogram(lk_ct)

# %% [markdown]
# #  model

# %%
hc = AgglomerativeClustering()
y = hc.fit_predict(scaled)

# %%
df['cluster_h']=y
df
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# ID#
# 1       28143           0          1          1          1          174
# 2       19244           0          1          1          1          215
# 3       41354           0          1          1          1         4123
# 4       14776           0          1          1          1          500
# 5       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 4017    18476           0          1          1          1         8525
# 4018    64385           0          1          1          1          981
# 4019    73597           0          3          1          1        25447
# 4020    54899           0          1          1          1          500
# 4021     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ID#
# 1               1                  0                0               7000
# 2               2                  0                0               6968
# 3               4                  0                0               7034
# 4               1                  0                0               6952
# 5              26               2077                4               6935
# ...           ...                ...              ...                ...
# 4017            4                200                1               1403
# 4018            5                  0                0               1395
# 4019            8                  0                0               1402
# 4020            1                500                1               1401
# 4021            0                  0                0               1398
#
#       Award  cluster_h
# ID#
# 1         0          1
# 2         0          1
# 3         0          1
# 4         0          1
# 5         1          0
# ...     ...        ...
# 4017      1          1
# 4018      1          1
# 4019      1          0
# 4020      0          1
# 4021      0          1
#
# [3998 rows x 12 columns]

# %%
df.groupby('cluster_h').agg('mean')
# Out:
#                  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# cluster_h
# 0          117912.886093  366.377483   3.406623   1.000000    1.03245
# 1           46737.239148    9.278135   1.242363   1.023312    1.00000
#
#             Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# cluster_h
# 0          37101.439735    19.037086         853.826490         2.483444
# 1           5039.817524     7.094051         221.256029         0.700563
#
#            Days_since_enroll     Award
# cluster_h
# 0                4688.513245  0.670861
# 1                3773.660370  0.188103

# %% [markdown]
# # Visualization

# %%
sns.scatterplot(x=df['Bonus_miles'],y=df['Days_since_enroll'],hue= df['cluster_h'],palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Bonus_miles', ylabel='Days_since_enroll'>

# %%
sns.scatterplot(x=df['Days_since_enroll'],y=df['Award'],hue= df['cluster_h'],palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Bonus_miles', ylabel='Days_since_enroll'>

# %%
sns.scatterplot(x=df['Days_since_enroll'],y=df['Flight_miles_12mo'],hue= df['cluster_h'],palette='rainbow')
# Out:
# <AxesSubplot:xlabel='Bonus_miles', ylabel='Days_since_enroll'>

# %%
silhouette_score(scaled,y)
# Out:
# 0.28915604880621426

# %% [markdown]
# # K-Means

# %%
km = KMeans()
y = km.fit_predict(scaled)

# %%
km.cluster_centers_
# Out:
# array([[ 4.25258375e-01,  7.09897334e+00,  9.40384936e-03,
#         -9.82542913e-02, -6.27744600e-02,  1.09946888e-01,
#          9.79636086e-02,  3.59140855e-01,  3.99928303e-01,
#         -8.16339914e-02,  3.24768269e-01],
#        [-1.53322142e-01, -5.84059557e-02, -2.64899456e-01,
#         -9.82542913e-02, -6.27744600e-02, -2.71832894e-01,
#         -1.03873056e-01, -2.75371542e-02, -2.07943445e-02,
#          6.55835577e-02,  1.30365921e+00],
#        [-1.38586873e-01, -1.43747122e-01, -4.04701406e-01,
#         -9.82542913e-02, -5.74887185e-02, -4.49433943e-01,
#         -3.22219137e-01, -2.02964853e-01, -2.21830948e-01,
#          7.38361420e-01, -7.67071631e-01],
#        [-3.87626292e-01, -1.44339130e-01, -5.88153469e-01,
#         -9.82542913e-02, -6.27744600e-02, -5.28296080e-01,
#         -5.21078753e-01, -2.21654862e-01, -2.43764143e-01,
#         -9.75376232e-01, -7.67071631e-01],
#        [ 1.24437893e+00,  4.86092753e-01,  2.36390118e-01,
#         -9.82542913e-02, -6.27744600e-02,  8.04703542e-01,
#          1.89953674e+00,  4.05482458e+00,  4.30327186e+00,
#          3.11635525e-01,  9.30248734e-01],
#        [ 6.39500591e-01, -8.44693245e-02,  1.02183982e+00,
#         -9.82542913e-02,  1.56443349e+01,  3.17931660e+00,
#          1.71441020e+00,  3.32067952e-02,  5.95983297e-02,
#          2.39581899e-01,  3.37318153e-01],
#        [ 6.42568967e-01, -1.06280431e-01,  1.55535493e+00,
#         -9.82542913e-02, -5.02820613e-02,  1.36962327e+00,
#          8.70121244e-01, -5.08729513e-02, -5.10001434e-02,
#          4.05791368e-01,  5.38498914e-01],
#        [-4.70670530e-02, -1.56263335e-01, -6.68385693e-01,
#          9.03710982e+00, -6.27744600e-02, -1.01836598e-01,
#          6.17584480e-01,  8.74574512e-02,  2.20232294e-01,
#         -7.27738996e-02,  5.15894006e-02]])

# %%
plt.scatter(x=scaled[:,0],y=scaled[:,1],c=y,cmap='rainbow')

# %%
plt.scatter(x=scaled[:,0],y=scaled[:,-2],c=y,cmap='rainbow')

# %%
silhouette_score(scaled,y)
# Out:
# 0.23669847546322711

# %% [markdown]
# # Elbow Graph

# %%
wcss=[]
for i in range(2,20):
    km = KMeans(n_clusters=i)
    km.fit_predict(scaled)
    wcss.append(km.inertia_)

# %%
plt.plot(range(2,20),wcss)
plt.title('Elbow Graph')
plt.axvline(8,linestyle='--',c='r')

# %% [markdown]
# # Kmeans Final

# %%
finalkmean= KMeans(n_clusters=8)
ypred = finalkmean.fit_predict(scaled)

# %%
silhouette_score(scaled,ypred)
# Out:
# 0.23128228401433282

# %%
sns.scatterplot(x=scaled[:,0],y=scaled[:,1],hue=ypred,palette='rainbow')
plt.scatter(finalkmean.cluster_centers_[:,0],finalkmean.cluster_centers_[:,1],color = 'black',s=100)

# %% [markdown]
# # Evaluate

# %%
model = SilhouetteVisualizer(KMeans(n_clusters=8))
vis = model.fit(scaled)
vis.show()
# Out:
# <AxesSubplot:title={'center':'Silhouette Plot of KMeans Clustering for 3998 Samples in 8 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>

# %%
df['clusterkm']=ypred
df.head()
# Out:
#      Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# ID#
# 1      28143           0          1          1          1          174
# 2      19244           0          1          1          1          215
# 3      41354           0          1          1          1         4123
# 4      14776           0          1          1          1          500
# 5      97752           0          4          1          1        43300
#
#      Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ID#
# 1              1                  0                0               7000
# 2              2                  0                0               6968
# 3              4                  0                0               7034
# 4              1                  0                0               6952
# 5             26               2077                4               6935
#
#      Award  cluster_h  clusterkm
# ID#
# 1        0          1          1
# 2        0          1          1
# 3        0          1          1
# 4        0          1          1
# 5        1          0          2

# %%
df.groupby('clusterkm').agg('mean')
# Out:
#                  Balance   Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# clusterkm
# 0          118527.293103  5486.241379   2.051724   1.000000   1.000000
# 1           59100.549103    62.119556   1.306576   1.000000   1.000854
# 2           89662.720822    50.765640   3.768441   1.000000   1.001867
# 3          449245.408696   241.982609   4.095652   1.000000   1.000000
# 4           36112.851562    36.579545   1.228693   1.000000   1.000000
# 5          125451.948718   422.957265   2.119658   1.000000   1.000000
# 6          138061.400000    78.800000   3.466667   1.000000   4.066667
# 7           68876.581395    23.255814   1.139535   2.348837   1.000000
#
#             Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# clusterkm
# 0          19386.500000    12.500000         980.724138         2.913793
# 1           5560.590948     7.823228         269.884714         0.818958
# 2          37934.146592    18.789916         305.511671         0.888889
# 3          73856.913043    23.182609        1228.460870         4.269565
# 4           4468.093040     6.526989         169.668324         0.519176
# 5          29689.735043    28.675214        6212.170940        17.709402
# 6          93927.866667    28.066667         506.666667         1.600000
# 7          14689.837209    17.534884         582.627907         2.209302
#
#            Days_since_enroll     Award  cluster_h
# clusterkm
# 0                3928.534483  0.551724   0.000000
# 1                5749.344150  0.294620   0.894962
# 2                4615.084034  0.658263   0.042017
# 3                6071.956522  0.791304   0.043478
# 4                2212.927557  0.136364   0.952415
# 5                4371.632479  0.777778   0.051282
# 6                4613.866667  0.533333   0.000000
# 7                3968.930233  0.395349   1.000000

# %% [markdown]
# # DBSCAN

# %%
db = DBSCAN(eps=0.5,min_samples=5)
y= db.fit_predict(scaled)

# %%
y
# Out:
# array([ 0,  0,  0, ..., -1,  0,  0], dtype=int64)

# %%
plt.scatter(x=scaled[:,0],y=scaled[:,1],c=y,cmap='rainbow')
plt.show()

# %%
silhouette_score(scaled,y)
# Out:
# -0.07847654973330041

# %% [markdown]
# # Hyperparameter Tuning

# %%
neigh = NearestNeighbors(n_neighbors=3).fit(scaled)
d,i=neigh.kneighbors(scaled)

# %%
d
# Out:
# array([[0.        , 0.11185195, 0.12033566],
#        [0.        , 0.11406716, 0.11438169],
#        [0.        , 0.16540105, 0.19458411],
#        ...,
#        [0.        , 0.16614444, 0.28024134],
#        [0.        , 0.25725538, 0.27165991],
#        [0.        , 0.00270567, 0.01129616]])

# %%
dist =np.sort(d[:,1])

# %%
plt.plot(dist)
plt.xlabel('Distance')
plt.ylabel('Epsilon Value')
plt.axhline(2,linestyle='--',c='r')

plt.show()

# %% [markdown]
# Epsilon value = 2

# %%
dbs = DBSCAN(eps=2, min_samples=12)
ypre = dbs.fit_predict(scaled)
ypre
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
silhouette_score(scaled,ypre)
# Out:
# 0.25532735902092807

# %%
dbs = DBSCAN(eps=2, min_samples=18)
ypre = dbs.fit_predict(scaled)
ypre
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
silhouette_score(scaled,ypre)
# Out:
# 0.2522827425697712

# %% [markdown]
# # Final DBSCAN

# %%
dbs = DBSCAN(eps=2, min_samples=12)
ypre = dbs.fit_predict(scaled)
ypre
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
silhouette_score(scaled,ypre)
# Out:
# 0.25532735902092807

# %%
plt.scatter(x=scaled[:,0], y=scaled[:,-2],c=ypre,cmap='rainbow')
plt.show()

# %%
df['cluster_db']=ypre
df
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# ID#
# 1       28143           0          1          1          1          174
# 2       19244           0          1          1          1          215
# 3       41354           0          1          1          1         4123
# 4       14776           0          1          1          1          500
# 5       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 4017    18476           0          1          1          1         8525
# 4018    64385           0          1          1          1          981
# 4019    73597           0          3          1          1        25447
# 4020    54899           0          1          1          1          500
# 4021     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ID#
# 1               1                  0                0               7000
# 2               2                  0                0               6968
# 3               4                  0                0               7034
# 4               1                  0                0               6952
# 5              26               2077                4               6935
# ...           ...                ...              ...                ...
# 4017            4                200                1               1403
# 4018            5                  0                0               1395
# 4019            8                  0                0               1402
# 4020            1                500                1               1401
# 4021            0                  0                0               1398
#
#       Award  cluster_h  clusterkm  cluster_db
# ID#
# 1         0          1          1           0
# 2         0          1          1           0
# 3         0          1          1           0
# 4         0          1          1           0
# 5         1          0          2           1
# ...     ...        ...        ...         ...
# 4017      1          1          4           1
# 4018      1          1          4           1
# 4019      1          0          2           1
# 4020      0          1          4           0
# 4021      0          1          4           0
#
# [3998 rows x 14 columns]

# %% [markdown]
# # cluster Insight

# %% [markdown]
# ## For hierarchical

# %%
df.groupby('cluster_h')[['Balance','Qual_miles','cc1_miles','cc2_miles','cc3_miles','Bonus_miles','Bonus_trans','Flight_miles_12mo','Flight_trans_12','Days_since_enroll','Award']].agg('mean')
# Out:
#                  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# cluster_h
# 0          117912.886093  366.377483   3.406623   1.000000    1.03245
# 1           46737.239148    9.278135   1.242363   1.023312    1.00000
#
#             Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# cluster_h
# 0          37101.439735    19.037086         853.826490         2.483444
# 1           5039.817524     7.094051         221.256029         0.700563
#
#            Days_since_enroll     Award
# cluster_h
# 0                4688.513245  0.670861
# 1                3773.660370  0.188103

# %% [markdown]
# ## For kmean

# %%
df.groupby('clusterkm')[['Balance','Qual_miles','cc1_miles','cc2_miles','cc3_miles','Bonus_miles','Bonus_trans','Flight_miles_12mo','Flight_trans_12','Days_since_enroll','Award']].agg('mean')
# Out:
#                  Balance   Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# clusterkm
# 0          118527.293103  5486.241379   2.051724   1.000000   1.000000
# 1           59100.549103    62.119556   1.306576   1.000000   1.000854
# 2           89662.720822    50.765640   3.768441   1.000000   1.001867
# 3          449245.408696   241.982609   4.095652   1.000000   1.000000
# 4           36112.851562    36.579545   1.228693   1.000000   1.000000
# 5          125451.948718   422.957265   2.119658   1.000000   1.000000
# 6          138061.400000    78.800000   3.466667   1.000000   4.066667
# 7           68876.581395    23.255814   1.139535   2.348837   1.000000
#
#             Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# clusterkm
# 0          19386.500000    12.500000         980.724138         2.913793
# 1           5560.590948     7.823228         269.884714         0.818958
# 2          37934.146592    18.789916         305.511671         0.888889
# 3          73856.913043    23.182609        1228.460870         4.269565
# 4           4468.093040     6.526989         169.668324         0.519176
# 5          29689.735043    28.675214        6212.170940        17.709402
# 6          93927.866667    28.066667         506.666667         1.600000
# 7          14689.837209    17.534884         582.627907         2.209302
#
#            Days_since_enroll     Award
# clusterkm
# 0                3928.534483  0.551724
# 1                5749.344150  0.294620
# 2                4615.084034  0.658263
# 3                6071.956522  0.791304
# 4                2212.927557  0.136364
# 5                4371.632479  0.777778
# 6                4613.866667  0.533333
# 7                3968.930233  0.395349

# %% [markdown]
# ## For DBscan

# %%
df.groupby('cluster_db')[['Balance','Qual_miles','cc1_miles','cc2_miles','cc3_miles','Bonus_miles','Bonus_trans','Flight_miles_12mo','Flight_trans_12','Days_since_enroll','Award']].agg('mean')
# Out:
#                   Balance   Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# cluster_db
# -1          225834.029167  1490.650000   2.675000      1.175   1.204167
#  0           57663.177049    42.624180   1.695902      1.000   1.000000
#  1           75887.015361    87.983871   2.641321      1.000   1.000000
#  2           39218.500000     0.000000   1.000000      2.000   1.000000
#
#              Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# cluster_db
# -1          47893.308333    25.491667        3325.745833         9.670833
#  0           9778.901639     8.890164         187.600820         0.547951
#  1          25391.933948    14.109063         445.843318         1.399386
#  2           9189.250000    13.500000         209.375000         0.812500
#
#             Days_since_enroll     Award
# cluster_db
# -1                4841.904167  0.745833
#  0                3813.595082  0.000000
#  1                4566.139785  1.000000
#  2                3511.187500  0.000000
