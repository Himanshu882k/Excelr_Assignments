# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = (10,10)
plt.rcParams['figure.dpi'] = 500
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.preprocessing import OrdinalEncoder
from sklearn.metrics import classification_report , confusion_matrix
sns.set_style('darkgrid')
plt.rcParams['figure.figsize'] = (10,5)

# %%
df = pd.read_csv('Fraud_check.csv')
df
# Out:
#     Undergrad Marital.Status  Taxable.Income  City.Population  \
# 0          NO         Single           68833            50047
# 1         YES       Divorced           33700           134075
# 2          NO        Married           36925           160205
# 3         YES         Single           50190           193264
# 4          NO        Married           81002            27533
# ..        ...            ...             ...              ...
# 595       YES       Divorced           76340            39492
# 596       YES       Divorced           69967            55369
# 597        NO       Divorced           47334           154058
# 598       YES        Married           98592           180083
# 599        NO       Divorced           96519           158137
#
#      Work.Experience Urban
# 0                 10   YES
# 1                 18   YES
# 2                 30   YES
# 3                 15   YES
# 4                 28    NO
# ..               ...   ...
# 595                7   YES
# 596                2   YES
# 597                0   YES
# 598               17    NO
# 599               16    NO
#
# [600 rows x 6 columns]

# %%
df.rename(columns={'Marital.Status':'MaritalStatus',
                  'Taxable.Income':'TaxableIncome',
                  'City.Population':'CityPopulation',
                  'Work.Experience': 'WorkExperience'},inplace=True)
df
# Out:
#     Undergrad MaritalStatus  TaxableIncome  CityPopulation  WorkExperience  \
# 0          NO        Single          68833           50047              10
# 1         YES      Divorced          33700          134075              18
# 2          NO       Married          36925          160205              30
# 3         YES        Single          50190          193264              15
# 4          NO       Married          81002           27533              28
# ..        ...           ...            ...             ...             ...
# 595       YES      Divorced          76340           39492               7
# 596       YES      Divorced          69967           55369               2
# 597        NO      Divorced          47334          154058               0
# 598       YES       Married          98592          180083              17
# 599        NO      Divorced          96519          158137              16
#
#     Urban
# 0     YES
# 1     YES
# 2     YES
# 3     YES
# 4      NO
# ..    ...
# 595   YES
# 596   YES
# 597   YES
# 598    NO
# 599    NO
#
# [600 rows x 6 columns]

# %% [markdown]
# # target column
# Given: treating those who have taxable_income <= 30000 as "Risky" and others are "Good"

# %%
df['Target']=df['TaxableIncome'].apply(lambda x: 'Risky' if x <= 30000 else"Good")
df
# Out:
#     Undergrad MaritalStatus  TaxableIncome  CityPopulation  WorkExperience  \
# 0          NO        Single          68833           50047              10
# 1         YES      Divorced          33700          134075              18
# 2          NO       Married          36925          160205              30
# 3         YES        Single          50190          193264              15
# 4          NO       Married          81002           27533              28
# ..        ...           ...            ...             ...             ...
# 595       YES      Divorced          76340           39492               7
# 596       YES      Divorced          69967           55369               2
# 597        NO      Divorced          47334          154058               0
# 598       YES       Married          98592          180083              17
# 599        NO      Divorced          96519          158137              16
#
#     Urban Target
# 0     YES   Good
# 1     YES   Good
# 2     YES   Good
# 3     YES   Good
# 4      NO   Good
# ..    ...    ...
# 595   YES   Good
# 596   YES   Good
# 597   YES   Good
# 598    NO   Good
# 599    NO   Good
#
# [600 rows x 7 columns]

# %% [markdown]
# # Visualization

# %%
sns.scatterplot(x=df['WorkExperience'],y=df['TaxableIncome'],hue=df['Target'])
# Out:
# <AxesSubplot:xlabel='WorkExperience', ylabel='TaxableIncome'>

# %%
sns.histplot(df['TaxableIncome'],kde=True)
# Out:
# <AxesSubplot:xlabel='TaxableIncome', ylabel='Count'>

# %% [markdown]
# # Decision Tree

# %%
x = df.iloc[:,:-1]
y=df['Target']

# %%
oe = OrdinalEncoder()
x[['Undergrad','MaritalStatus','Urban']] = oe.fit_transform(x[['Undergrad','MaritalStatus','Urban']])

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# # 1) C5.0 Decision Tree

# %%
dtc = DecisionTreeClassifier(criterion='entropy').fit(xtrain,ytrain)

# %%
print('Test Report')
print(classification_report(ytest,dtc.predict(xtest)))
# Out:
# Test Report
#               precision    recall  f1-score   support
#
#         Good       1.00      1.00      1.00        94
#        Risky       1.00      1.00      1.00        26
#
#     accuracy                           1.00       120
#    macro avg       1.00      1.00      1.00       120
# weighted avg       1.00      1.00      1.00       120

# %%
print(f"Training Accuracy is:  {dtc.score(xtrain,ytrain)}")
print(f"Training Accuracy is:  {dtc.score(xtest,ytest)}")
# Out:
# Training Accuracy is:  1.0
# Training Accuracy is:  1.0

# %%
ypred  = dtc.predict(xtest)
ypred
# Out:
# array(['Risky', 'Good', 'Good', 'Good', 'Risky', 'Risky', 'Risky', 'Good',
#        'Good', 'Risky', 'Risky', 'Risky', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Risky', 'Good', 'Risky', 'Good', 'Risky',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Risky', 'Good', 'Good', 'Risky', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Risky', 'Good', 'Good', 'Risky', 'Risky',
#        'Good', 'Good', 'Risky', 'Good', 'Good', 'Good', 'Risky', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Risky', 'Risky',
#        'Risky', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Risky', 'Risky', 'Risky', 'Good', 'Good', 'Good', 'Risky', 'Good',
#        'Risky', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Risky'],
#       dtype=object)

# %%
sns.heatmap(confusion_matrix(ytest,ypred),annot=True)
plt.title('Confusion Matrix')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
tree.plot_tree(dtc,feature_names=x.columns,class_names=df['Target'].unique(),filled=True)
# Out:
# [Text(0.5, 0.75, 'TaxableIncome <= 30041.5\nentropy = 0.73\nsamples = 480\nvalue = [382, 98]\nclass = Good'),
#  Text(0.25, 0.25, 'entropy = 0.0\nsamples = 98\nvalue = [0, 98]\nclass = Risky'),
#  Text(0.75, 0.25, 'entropy = 0.0\nsamples = 382\nvalue = [382, 0]\nclass = Good')]

# %% [markdown]
# # 2) CART

# %%
dt_c = DecisionTreeClassifier(criterion='gini').fit(xtrain,ytrain)

# %%
print(f"Training Accuracy is:  {dt_c.score(xtrain,ytrain)}")
print(f"Training Accuracy is:  {dt_c.score(xtest,ytest)}")
# Out:
# Training Accuracy is:  1.0
# Training Accuracy is:  1.0

# %%
print('Test Report')
print(classification_report(ytest,dt_c.predict(xtest)))
# Out:
# Test Report
#               precision    recall  f1-score   support
#
#         Good       1.00      1.00      1.00        94
#        Risky       1.00      1.00      1.00        26
#
#     accuracy                           1.00       120
#    macro avg       1.00      1.00      1.00       120
# weighted avg       1.00      1.00      1.00       120

# %%
ypred  = dt_c.predict(xtest)
ypred
# Out:
# array(['Risky', 'Good', 'Good', 'Good', 'Risky', 'Risky', 'Risky', 'Good',
#        'Good', 'Risky', 'Risky', 'Risky', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Risky', 'Good', 'Risky', 'Good', 'Risky',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Risky', 'Good', 'Good', 'Risky', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Risky', 'Good', 'Good', 'Risky', 'Risky',
#        'Good', 'Good', 'Risky', 'Good', 'Good', 'Good', 'Risky', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Risky', 'Risky',
#        'Risky', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Risky', 'Risky', 'Risky', 'Good', 'Good', 'Good', 'Risky', 'Good',
#        'Risky', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Risky'],
#       dtype=object)

# %%
sns.heatmap(confusion_matrix(ytest,ypred),annot=True)
plt.title('Confusion Matrix')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix')

# %%
tree.plot_tree(dt_c,feature_names=x.columns,class_names=df['Target'].unique(),filled=True)
# Out:
# [Text(0.5, 0.75, 'TaxableIncome <= 30041.5\ngini = 0.325\nsamples = 480\nvalue = [382, 98]\nclass = Good'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 98\nvalue = [0, 98]\nclass = Risky'),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 382\nvalue = [382, 0]\nclass = Good')]
