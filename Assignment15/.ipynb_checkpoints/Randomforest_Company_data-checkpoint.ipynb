# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = (10,10)
plt.rcParams['figure.dpi'] = 500
from sklearn.model_selection import train_test_split , GridSearchCV
from sklearn.ensemble import RandomForestRegressor 
from sklearn import tree
from sklearn.metrics import classification_report , confusion_matrix
sns.set_style('darkgrid')
plt.rcParams['figure.figsize'] = (10,5)

# %%
df = pd.read_csv('Company_Data.csv')
df
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# 0           17   Yes  Yes
# 1           10   Yes  Yes
# 2           12   Yes  Yes
# 3           14   Yes  Yes
# 4           13   Yes   No
# ..         ...   ...  ...
# 395         14   Yes  Yes
# 396         11    No  Yes
# 397         18   Yes  Yes
# 398         12   Yes  Yes
# 399         16   Yes  Yes
#
# [400 rows x 11 columns]

# %% [markdown]
# # Data Preprocessing

# %%
df = pd.get_dummies(df,columns=['ShelveLoc','Urban','US'], drop_first=True)
df
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  Age  Education  \
# 0     9.50        138      73           11         276    120   42         17
# 1    11.22        111      48           16         260     83   65         10
# 2    10.06        113      35           10         269     80   59         12
# 3     7.40        117     100            4         466     97   55         14
# 4     4.15        141      64            3         340    128   38         13
# ..     ...        ...     ...          ...         ...    ...  ...        ...
# 395  12.57        138     108           17         203    128   33         14
# 396   6.14        139      23            3          37    120   55         11
# 397   7.41        162      26           12         368    159   40         18
# 398   5.94        100      79            7         284     95   50         12
# 399   9.71        134      37            0          27    120   49         16
#
#      ShelveLoc_Good  ShelveLoc_Medium  Urban_Yes  US_Yes
# 0                 0                 0          1       1
# 1                 1                 0          1       1
# 2                 0                 1          1       1
# 3                 0                 1          1       1
# 4                 0                 0          1       0
# ..              ...               ...        ...     ...
# 395               1                 0          1       1
# 396               0                 1          0       1
# 397               0                 1          1       1
# 398               0                 0          1       1
# 399               1                 0          1       1
#
# [400 rows x 12 columns]

# %% [markdown]
# # Visualization

# %%
sns.scatterplot(x=df['Education'],y=df['Income'])
# Out:
# <AxesSubplot:xlabel='Education', ylabel='Income'>

# %%
sns.scatterplot(x=df['Age'],y=df['Income'])
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Income'>

# %%
sns.scatterplot(x=df['CompPrice'],y=df['Sales'])
# Out:
# <AxesSubplot:xlabel='CompPrice', ylabel='Sales'>

# %% [markdown]
# # Random Forest

# %%
x= df.drop('Sales',axis=1)
y = df['Sales']

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
dt_r = RandomForestRegressor().fit(xtrain,ytrain)

# %%
print(f"Training Accuracy is:  {dt_r.score(xtrain,ytrain)}")
print(f"Training Accuracy is:  {dt_r.score(xtest,ytest)}")
# Out:
# Training Accuracy is:  0.9542078564399195
# Training Accuracy is:  0.6892562022800797

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = { 
    'criterion':['squared_error', 'absolute_error','friedman_mse'],
    'max_depth' :[10,15,20,25]
}
grid = GridSearchCV(RandomForestRegressor(),params,verbose=1).fit(xtrain,ytrain)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits

# %%
grid.best_score_ , grid.best_params_
# Out:
# (0.6211519873557825, {'criterion': 'squared_error', 'max_depth': 20})

# %%
grid.best_estimator_.score(xtest,ytest)
# Out:
# 0.6921657158076636

# %%
grid.best_estimator_.score(xtrain,ytrain)
# Out:
# 0.9552910249280525

# %% [markdown]
# The default Tree give better performance

# %%
dt_r = RandomForestRegressor(n_estimators=500,criterion='friedman_mse',max_depth=15).fit(xtrain,ytrain)

# %% [markdown]
# # Feature Importance

# %%
dt_r.feature_importances_
# Out:
# array([0.09277279, 0.05148217, 0.08492988, 0.04044447, 0.31429926,
#        0.11830656, 0.03142771, 0.19879079, 0.05552514, 0.0065455 ,
#        0.00547573])

# %%
feature_df = pd.DataFrame({'Feature':x.columns,
                          'Importance':dt_r.feature_importances_})
feature_df.sort_values('Importance',ascending=False,inplace=True)

# %%
feature_df
# Out:
#              Feature  Importance
# 4              Price    0.314299
# 7     ShelveLoc_Good    0.198791
# 5                Age    0.118307
# 0          CompPrice    0.092773
# 2        Advertising    0.084930
# 8   ShelveLoc_Medium    0.055525
# 1             Income    0.051482
# 3         Population    0.040444
# 6          Education    0.031428
# 9          Urban_Yes    0.006546
# 10            US_Yes    0.005476

# %%
sns.barplot(data=feature_df,y='Feature',x='Importance',palette='Accent')
# Out:
# <AxesSubplot:xlabel='Importance', ylabel='Feature'>

# %% [markdown]
# Price has highest importance
